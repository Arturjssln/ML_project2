# %%
MODEL_V2_004 = {
    "path": './BEST_V3.DEEP5.1-saved_weights.h5',
    "test_accuracy": None,
    "test_f1": None,
    "test_loss": None,
    "test_IOU": None,
    "batchnorm": True,
    "residual": True,
}

DEFAULT = {
    "mode": 'rgb',
    "seed": 1000,
    "lk_alpha": .1,
    "channels_size": 3,
    "batchnorm": True,
    "residual": True,
}

MODEL_TO_IMPORT = MODEL_V2_004 # can be either a model (dict) or a string

IMAGE_SIZE = 608
PATCH_SIZE = 16
PTHRESHOLD = 0.25
NB_TST_IMG = 50

# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import os, sys
from PIL import Image
import re
from IPython import display

# %%
root_dir = "."
test_dir = os.path.join(root_dir, "test_set_images/test_")

# %%
def get_model_prop(prop_name):
    if isinstance(MODEL_TO_IMPORT, str) or prop_name not in MODEL_TO_IMPORT:
        return DEFAULT[prop_name]
    return MODEL_TO_IMPORT[prop_name]

# %%
from CNNv2 import CNN

model = CNN(
    rootdir=root_dir,
    window_size=IMAGE_SIZE,
    lk_alpha=get_model_prop('lk_alpha'),
    random_seed=get_model_prop('seed'),
    channels_size=get_model_prop('channels_size'),
    batchnorm=get_model_prop('batchnorm'),
    residual=get_model_prop('residual'),
)
model_path = MODEL_TO_IMPORT if isinstance(MODEL_TO_IMPORT, str) else MODEL_TO_IMPORT['path']
model.load(os.path.join(root_dir, model_path))
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 608, 608, 3)  0
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 608, 608, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 608, 608, 64) 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 608, 608, 64) 36928       batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 608, 608, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 608, 608, 67) 0           input_2[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 304, 304, 67) 0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 304, 304, 128 77312       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 304, 304, 128 512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 304, 304, 128 147584      batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 304, 304, 128 512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 304, 304, 195 0           max_pooling2d_5[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 152, 152, 195 0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 152, 152, 256 449536      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 152, 152, 256 1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 152, 152, 256 590080      batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 152, 152, 256 1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 152, 152, 451 0           max_pooling2d_6[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 76, 76, 451)  0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 76, 76, 512)  2078720     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 76, 76, 512)  2048        conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 76, 76, 512)  2359808     batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 76, 76, 512)  2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 76, 76, 963)  0           max_pooling2d_7[0][0]
#                                                                  batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 38, 38, 963)  0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 38, 38, 1024) 8876032     max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 38, 38, 1024) 4096        conv2d_32[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 38, 38, 1024) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 38, 38, 1024) 9438208     dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 38, 38, 1024) 4096        conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 38, 38, 1987) 0           max_pooling2d_8[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 76, 76, 1987) 0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 76, 76, 512)  4069888     up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 76, 76, 1475) 0           concatenate_17[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 76, 76, 512)  6797312     concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 76, 76, 512)  2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 76, 76, 512)  2359808     batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 76, 76, 512)  2048        conv2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 76, 76, 1987) 0           concatenate_19[0][0]
#                                                                  batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 152, 152, 198 0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 152, 152, 256 2034944     up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 152, 152, 707 0           concatenate_16[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 152, 152, 256 1629184     concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 152, 152, 256 1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 152, 152, 256 590080      batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 152, 152, 256 1024        conv2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 152, 152, 963 0           concatenate_21[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 304, 304, 963 0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 304, 304, 128 493184      up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 304, 304, 323 0           concatenate_15[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 304, 304, 128 372224      concatenate_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 304, 304, 128 512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 304, 304, 128 147584      batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 304, 304, 128 512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 304, 304, 451 0           concatenate_23[0][0]
#                                                                  batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 608, 608, 451 0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 608, 608, 64) 115520      up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 608, 608, 131 0           concatenate_14[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 608, 608, 64) 75520       concatenate_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 608, 608, 64) 256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 608, 608, 64) 36928       batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 608, 608, 64) 256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 608, 608, 195 0           concatenate_25[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 608, 608, 1)  196         concatenate_26[0][0]
# ==================================================================================================
# Total params: 42,801,924
# Trainable params: 42,790,148
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-56ccf4674cfb> in <module>
#      11 )
#      12 model_path = MODEL_TO_IMPORT if isinstance(MODEL_TO_IMPORT, str) else MODEL_TO_IMPORT['path']
# ---> 13 model.load(os.path.join(root_dir, model_path))
#
# ~\Documents\GitHub\ML_project2\src\sven\custom2\CNNv2.py in load(self, filename)
#     299     def load(self, filename):
#     300         """ Load the weights for this model from a file. """
# --> 301         self.model.load_weights(filename)
#
# ~\.conda\envs\ML2\lib\site-packages\keras\engine\saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# ~\.conda\envs\ML2\lib\site-packages\keras\engine\network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1228             else:
#    1229                 saving.load_weights_from_hdf5_group(
# -> 1230                     f, self.layers, reshape=reshape)
#    1231             if hasattr(f, 'close'):
#    1232                 f.close()
#
# ~\.conda\envs\ML2\lib\site-packages\keras\engine\saving.py in load_weights_from_hdf5_group(f, layers, reshape)
#    1207                          'containing ' + str(len(layer_names)) +
#    1208                          ' layers into a model with ' +
# -> 1209                          str(len(filtered_layers)) + ' layers.')
#    1210
#    1211     # We batch weight value assignments in a single backend call
#
# ValueError: You are trying to load a weight file containing 50 layers into a model with 41 layers.

# %%
from helpers import *
from skimage.color import rgb2hsv, rgb2lab, rgb2hed, rgb2yuv

def load_image(filename, mode = 'rgb'):
    if mode == 'hsv':
        img = rgb2hsv(mpimg.imread(filename))
    elif mode == 'lab':
        img = rgb2lab(mpimg.imread(filename))
    elif mode == 'hed':
        img = rgb2hed(mpimg.imread(filename))
    elif mode == 'yuv':
        img = rgb2yuv(mpimg.imread(filename))
    elif mode == 'rgb':
        img = mpimg.imread(filename)
    else:
        raise NotImplemented
    return np.expand_dims(img, axis=0)

def get_path_for_img_nb(img_nb):
    return test_dir+str(img_nb)+'/test_' + str(img_nb) + '.png'

def get_image_filenames(img_nb = None):
    image_filenames = []
    if img_nb == None:
        for i in range(1, NB_TST_IMG+1):
            image_filenames += [get_path_for_img_nb(i)]
    elif type(img_nb) is int:
        image_filenames += [get_path_for_img_nb(img_nb)]
    else:
        for i in img_nb:
            image_filenames += [get_path_for_img_nb(i)]
    return image_filenames
    
def visualize_step(idx, input_image, Xi_raw, Xi, ground, animate = False):
    input_image = np.squeeze(input_image)
    fig, axs = plt.subplots(1, 4, figsize=(16, 16))
    axs[0].imshow(input_image)
    axs[0].set_title(f'image {idx+1}')
    axs[1].imshow(np.squeeze(Xi_raw))
    axs[1].set_title('real prediction')
    axs[2].imshow(np.squeeze(Xi))
    axs[2].set_title('thresholded prediction')
    axs[3].imshow(ground)
    axs[3].set_title('label prediction')
    # remove the x and y ticks
    for ax in axs:
        ax.set_xticks([])
        ax.set_yticks([])
    display.clear_output(wait=True)
    if animate:
        plt.show()

def get_predicted_mask(image_filename, mode):
    input_image = load_image(image_filename, mode)
    Xi_raw = model.model.predict(input_image)
    Xi = np.where(Xi_raw>0.5, 1, 0)
    Xi = np.squeeze(Xi)
    return Xi_raw, Xi

def visualize(img_nb = None, mode = 'rgb', save_masks = False):
    image_filenames = get_image_filenames(img_nb)
    for i, filename in enumerate(image_filenames[0:]):
        img_input = load_image(filename, mode)
        Xi_raw, Xi = get_predicted_mask(filename, mode)
        ground = get_ground_img(Xi, patch_size = PATCH_SIZE, foreground_threshold = PTHRESHOLD)
        visualize_step(i, img_input, Xi_raw, Xi, ground)
        if save_masks:
            mpimg.imsave(os.path.join(root_dir, 'masks', f'test_{i+1}.png'), np.squeeze(Xi_raw[0]))
    plt.show()
        
def generate_submission(img_nb = None, plot = True, submission_filename = "submission.csv", mode = DEFAULT['mode']):
    """ Generate a .csv containing the classification of the test set. """
    image_filenames = get_image_filenames(img_nb)
    print(f'Generating file: {submission_filename}...')
    with open(os.path.join(root_dir, submission_filename), 'w') as f:
        f.write('id,prediction\n')
        for i, filename in enumerate(image_filenames[0:]):
            img_input = load_image(filename, mode)
            Xi_raw, Xi = get_predicted_mask(filename, mode)
            ground = get_ground_img(Xi, patch_size = PATCH_SIZE, foreground_threshold = PTHRESHOLD)
            if plot:
                visualize_step(i, img_input, Xi_raw, Xi, ground, True)
            else:
                print(f'Img {i+1}...')
            f.writelines([
                "{:03d}_{}_{},{}\n".format(i+1, j*PATCH_SIZE, k*PATCH_SIZE, ground[k,j])
                for j in range(ground.shape[1]) for k in range(ground.shape[0])
            ])
    print(f'Submission generated at {submission_filename}!')

# %%
visualize([1,2,6,10])
